# %% [raw]
# This code generates a line plot of random data with areas above 195 filled in green. It uses NumPy for random data generation and matplotlib for plotting and visualization.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor= 'g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [raw]
# This code imports the pandas library

# %%
import pandas as pd

# %% [raw]
# This code reads a CSV file from the provided URL and loads it into a pandas DataFrame called df. The CSV contains salary data, and pandas' read_csv() function is used to import the file for analysis.

# %%
df = pd.read_csv ("https://raw.githubusercontent.com/Apress/data-analysis-and-visualization-using-python/master/Ch07/Salaries.csv")

# %% [raw]
# This code displays the first 5 rows of the DataFrame df, giving a quick preview of the data.

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [raw]
# This code displays the last 10 rows of the DataFrame df, allowing you to view the most recent entries in the data.

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %% [raw]
# This code displays the first 10 rows of the DataFrame df, giving an overview of the initial entries in the data.

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %% [raw]
# This code displays the data types of each column in the DataFrame df, helping you understand what kind of data (e.g., integers, floats, strings) each column contains.

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [raw]
# This code returns the names of all the columns in the DataFrame df, allowing you to see the structure of the data.

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %% [raw]
# This code returns the axes of the DataFrame df, which includes the row index (axis 0) and the column index (axis 1). It provides a representation of the structure of the DataFrame.

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %% [raw]
# The code df.size returns the total number of elements in a pandas DataFrame df, which is equivalent to the product of the number of rows and columns in the DataFrame.

# %%
df.size
# Out:
# 468

# %% [raw]
# The code df.shape returns a tuple representing the dimensionality of a pandas DataFrame df, where the first element is the number of rows and the second element is the number of columns.

# %%
df.shape
# Out:
# (78, 6)

# %% [raw]
# The code df.values returns a NumPy ndarray representing the values in a pandas DataFrame df, where each element is a value in the DataFrame, arranged in a 2-dimensional array.

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [raw]
# The code df.describe() generates a summary of the central tendency, dispersion, and shape of a pandas DataFrame df, excluding object-type columns, providing an overview of the distribution of values in each column.

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %% [raw]
# The code df.min() returns the minimum value in each column of a pandas DataFrame df, or the minimum value in the entire DataFrame if axis=None.

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %% [raw]
# The code df.max() returns the maximum value in each column of a pandas DataFrame df, or the maximum value in the entire DataFrame if axis=None.

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %% [raw]
# The code df.salary accesses a column named "salary" in a pandas DataFrame df, returning a pandas Series containing the values in that column.

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [raw]
# The code df.sort_values(['salary'], ascending = True) sorts a pandas DataFrame df in ascending order based on the values in the "salary" column.

# %%
df.sort_values(['salary'], ascending = True)
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 57   AsstProf          A    3        1  Female   72500
# ..        ...        ...  ...      ...     ...     ...
# 31       Prof          B   22       21    Male  155750
# 27       Prof          A   45       43    Male  155865
# 72       Prof          B   24       15  Female  161101
# 13       Prof          B   35       33    Male  162200
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %% [raw]
# The code df.groupby('rank')[['salary']].mean() groups a pandas DataFrame df by the values in the "rank" column and calculates the mean salary for each group.

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %% [raw]
# The code df_sub = df[df['salary'] > 100000] creates a new DataFrame df_sub that includes only the rows from the original DataFrame df where the value in the "salary" column is greater than 100000.

# %%
df_sub = df[df['salary'] > 100000]

# %% [raw]
# The code df_sub.head() displays the first few rows of the new DataFrame df_sub, typically 5 rows by default, allowing you to preview the data in the resulting DataFrame.

# %%
df_sub.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800
# 5  Prof          A   20       20  Male  122400
